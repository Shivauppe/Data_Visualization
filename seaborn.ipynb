# %%
pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.2.5_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# seaborn numerical data sets
# relplot has options of plotting both categorical and numerical data
#relplot how the relationship between two variables 
# relplot >> relationship plot

# %%
#how tip is varying wrt to total_bill >> scatterplot/by default relplot scatter plot
# Figure-level interface for drawing relational plots onto a FacetGrid.

sns.relplot(x = 'total_bill' , y = 'tip', data = df)

# %%
sns.relplot(x = 'total_bill' , y = 'tip', data = df, hue = 'smoker') # relationship beetween two variables

# %%
sns.relplot(x = 'total_bill' , y = 'tip', data = df, hue = 'size') # relationship beetween two variables

# %%
# hue - diff color coding to give the more insights.
sns.relplot(x = 'total_bill' , y = 'tip', data = df, style = 'size') 
#style gives the diff reprentaion of diff columns

# %%
sns.relplot(x = 'total_bill' , y = 'tip', data = df, style = 'smoker', hue = 'time')

# %%
#relplot for making a line plot >> generating a plot
#line plot >> to understand the trend in a data , a time column/sequence is generally is there

# %%
import numpy as np
import pandas as pd
time = np.arange(500)
value = np.random.randn(500).cumsum()
df1 = pd.DataFrame({'time' :time ,'value ':value})

# %%
df1
# Out:
#      time     value
# 0       0   1.176880
# 1       1   1.510576
# 2       2   1.659276
# 3       3   1.277785
# 4       4   1.547749
# ..    ...        ...
# 495   495  36.655896
# 496   496  37.327677
# 497   497  36.711401
# 498   498  37.638990
# 499   499  35.991332
#
# [500 rows x 2 columns]

# %%
sns.relplot(x =time, y=value, kind = 'line',data = df1, sort = True)

# %%
fmri = sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri)

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, errorbar = 'sd')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, errorbar = 'sd', hue = 'event')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, errorbar = 'sd', hue = 'event', style = 'region')

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, errorbar = 'sd', 
            hue = 'event', style = 'region', dashes = False, markers = True)

# %%
df = sns.load_dataset('tips')

# %%
sns.relplot(x = 'total_bill', y = 'tip' ,hue = 'smoker', data = df)

# %%
sns.relplot(x = 'total_bill', y = 'tip' ,hue = 'smoker', data = df, col = 'time')

# %%
sns.relplot(x = 'total_bill', y = 'tip' ,hue = 'smoker', data = df, col = 'size')

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.catplot(x = 'day', y = 'total_bill' , data = df)
# insights - Many people are visiting on weekends compared to weekdays

# %%
# in catplot few plots are overlapping due to density - we are not clear here , so we can use swarm

sns.catplot(x = 'day', y = 'total_bill' , data = df, kind = 'swarm')

# %%
# box plot  >> to see outliers

# %%
sns.catplot(x = 'day', y = 'total_bill', data = df, kind = 'box')

# %%
sns.catplot(x = 'day', y = 'total_bill', data = df, kind = 'violin',)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x = 'day', y = 'total_bill', data = df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = df.total_bill, y = df.tip, kind = 'reg')

# %%
# joint plot - to understand the relationship and distribution of two variables(tip and total_bill)

# %%
sns.jointplot(x = df.total_bill, y = df.tip, kind = 'hex')

# %%
sns.jointplot(x = df.total_bill, y = df.tip, kind = 'kde') # kde - kernal density estimeter,
# contour >> metorological department

# %%
sns.pairplot(df) #makes a plots scatter plot with respect to all numerical column

# %%
sns.pairplot(df, hue = 'smoker')

# %%
sns.pairplot(df, hue = 'smoker', palette = 'coolwarm')
